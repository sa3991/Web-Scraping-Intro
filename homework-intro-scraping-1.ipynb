# %% [markdown]
# # Homework: Intro Scraping Practice
#
# In this assignment, we'll practicing our scraping skills by examining the "Published Reproductions" section of Soma's Investigate.ai project: https://investigate.ai/

# %% [markdown]
# ### 0) Setup
#
# Import `requests`, `BeautifulSoup`, and `pandas`. Remember that, even though we installed the library as `pip install beautifulsoup4`, the import statement uses a slightly different name.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ### 1) Grab the HTML for https://investigate.ai/
#
# Use `requests` to get the HTML, assigning it to a variable

# %%
investigate_html = requests.get("https://investigate.ai/").text
print(investigate_html[:200])
# Out:
# <!doctype html>
# <html lang="en-US">
#
#
#
# <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async src="https://www.googletagmanager.com/gtag/js?id=UA-5541738-27"></script>
#   <scrip

# %% [markdown]
# ### 2) Use `BeautifulSoup` to convert the HTML into its DOM representation

# %%
soup = BeautifulSoup(investigate_html)
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### 3) Use `.select(...)` to select *just* the "Published reproductions" section
#
#
# You'll want "View Source" or pop open the Element Inspector to figure out which element to target.
#
# Reminder: An element's `class` attribute can contain *multiple* classes, separated by spaces. For example: `<div class="potato hamburger">Hello</div>` has two classes, `potato` and `hamburger`. A CSS selector for *either* of the classes — `soup.select(".potato")` *or* `soup.select(".hamburger")` — will both match that element.
#
# Hint: Look for a `div` with a particular class.

# %%
projects_section = soup.select(".section-projects")
projects_section
# Out:
# [<div class="content section-projects">
#  <div class="columns">
#  <div class="column col-sm-auto col-8 col-mx-auto text-center">
#  <h3>Published reproductions</h3>
#  <p>Data science and machine learning can be used anywhere! From a small visualization at The Upshot to a year-long investigations by Reveal, let's try to put these new skills in context.</p>
#  </div>
#  <div class="column col-12">
#  <div class="columns">
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/nyt-takata-airbags/">Searching for faulty airbags in vehicle complaints</a></h5>
#  </div>
#  <div class="card-body">
#  <p>The National Highway Transportation Safety Administration receives thousands and thousands of vehicle complaints each year. Can we train a computer to filter out leads on Takata airbag malfunctions?</p>
#  </div>
#  <div class="card-footer">
#                          The New York Times
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/latimes-crime-classification/">Building a crime classification engine</a></h5>
#  </div>
#  <div class="card-body">
#  <p>Using machine learning as an investigative tool to cast light on years of underreporting by the Los Angeles Police Department.</p>
#  </div>
#  <div class="card-footer">
#                          Los Angeles Times
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/caixin-museum-word-count/">Chinese museum analysis</a></h5>
#  </div>
#  <div class="card-body">
#  <p>A word-count analysis of the names of around 4500 museums in China.</p>
#  </div>
#  <div class="card-footer">
#                          Caixin
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/wapo-app-reviews/">Analyzing online safety through app store reviews</a></h5>
#  </div>
#  <div class="card-body">
#  <p>After downloading over a hundred thousand reviews of "random chat apps," how to find reports of bullying, racism, and unwanted sexual behavior.</p>
#  </div>
#  <div class="card-footer">
#                          The Washington Post
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/ajc-doctors-abuse/">Uncovering abusive doctors that were allowed to continue practicing</a></h5>
#  </div>
#  <div class="card-body">
#  <p>How to comb through 100,000 disciplinary documents without reading each individual one.</p>
#  </div>
#  <div class="card-footer">
#                          Atlanta Journal-Constitution
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/upshot-trump-emolex/">Analyzing the tone of Trump's speeches</a></h5>
#  </div>
#  <div class="card-body">
#  <p>Standard sentiment analysis scores a document on a positive-vs-negative scale. Using the Emotional Lexicon, though, you can add unique emotional measurements like anger, joy, surprise, or fear.</p>
#  </div>
#  <div class="card-footer">
#                          The New York Times
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/azcentral-text-reuse-model-legislation/">Detecting special interest model legislation in state laws</a></h5>
#  </div>
#  <div class="card-body">
#  <p>Special interest groups use model legislation to push their agendas in state government. How can we find bills based on these "cut and paste" models?</p>
#  </div>
#  <div class="card-footer">
#                          USA Today, The Arizona Republic, and the Center for Public Integrity
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/fcc-comments/">Detecting bots in FCC comment submissions</a></h5>
#  </div>
#  <div class="card-body">
#  <p>The comment period on the FCC's net neutrality decision was flooded with bots. See how one still-in-training data scientist tackled finding re-used comments.</p>
#  </div>
#  <div class="card-footer">
#  </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/bloomberg-tweet-topics/">Figuring out what Democratic candidates care about</a></h5>
#  </div>
#  <div class="card-body">
#  <p>In the wide field of Democratic presidential candidates, who cares about what topics and how do these topics change over time?</p>
#  </div>
#  <div class="card-footer">
#                          Bloomberg
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/nyt-trump-tweets/">What does Trump tweet about?</a></h5>
#  </div>
#  <div class="card-body">
#  <p>What does Trump tweet about? An analysis of over 11,000 tweets.</p>
#  </div>
#  <div class="card-footer">
#                          The New York Times
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/ap-regression-unemployment/">Examining life expectancy at the local level</a></h5>
#  </div>
#  <div class="card-body">
#  <p>Combine geographically granular life expectancy data with the American Community Survey to see how poverty, education, income, and demographics can affect a community.</p>
#  </div>
#  <div class="card-footer">
#                          The Associated Press
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/fivethirtyeight-p-hacking/">p values and p-hacking</a></h5>
#  </div>
#  <div class="card-body">
#  <p>p-values and the quest for "statistical significance"</p>
#  </div>
#  <div class="card-footer">
#                          FiveThirtyEight
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/milwaukee-potholes/">Predicting delays in patching potholes based on demographics</a></h5>
#  </div>
#  <div class="card-body">
#  <p>An analysis of the relationship between race and city sanitation services in Milwaukee.</p>
#  </div>
#  <div class="card-footer">
#                          Milwaukee Journal-Sentinel
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/dmn-texas-school-cheating/">Finding cheating schools in Texas with linear regression</a></h5>
#  </div>
#  <div class="card-body">
#  <p>Some schools in Texas had an odd jump in standardized test scores between different grades. Was it cheating? Linear regression is on the case!</p>
#  </div>
#  <div class="card-footer">
#                          Dallas Morning News
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/tampa-bay-times-schools/">Measuring the impact of re-segregation on Florida elementary schools</a></h5>
#  </div>
#  <div class="card-body">
#  <p>Using race, income, and other data to predict the performance of schools in Pinellas County, Florida. Along with a linear regression-driven critique.</p>
#  </div>
#  <div class="card-footer">
#                          Tampa Bay Times
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/car-crashes-weight-regression/">Analyzing whether larger cars cause more deadly crashes</a></h5>
#  </div>
#  <div class="card-body">
#  <p>Reproducing a research paper on the impact of weight on car accidents, along with a look at a state-based car crash database.</p>
#  </div>
#  <div class="card-footer">
#                          Review of Economic Studies
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/propublica-opportunity-gap/">Tracking equal access to school programs</a></h5>
#  </div>
#  <div class="card-body">
#  <p>Looking at differences in access to advanced classes between schools with wealthy students and schools with poor students.</p>
#  </div>
#  <div class="card-footer">
#                          ProPublica
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/boston-globe-tickets/">Investigating who gets a ticket and who gets a warning</a></h5>
#  </div>
#  <div class="card-body">
#  <p>A classic piece of data journalism analyzing ticketing by Massachusetts police, and whether the race or gender of the driver might change the outcome.</p>
#  </div>
#  <div class="card-footer">
#                          The Boston Globe
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/stanford-open-policing/">Stanford Open Policing Data</a></h5>
#  </div>
#  <div class="card-body">
#  <p>A giant dataset of standardized data policing data across different states</p>
#  </div>
#  <div class="card-footer">
#  </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/buzzfeed-spy-planes/">Uncovering surveillance planes with BuzzFeed</a></h5>
#  </div>
#  <div class="card-body">
#  <p>From a list of points along a flight's path, how can you say "this looks like a surveillance plane?" And once you've found them, what do you do with the results?</p>
#  </div>
#  <div class="card-footer">
#                          BuzzFeed News
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/reveal-mortgages/">Analyzing mortgage rejections for racial bias</a></h5>
#  </div>
#  <div class="card-body">
#  <p>Based on government-mandated data collection on mortgage granting, are certain banks or areas discriminatory in their lending practices?</p>
#  </div>
#  <div class="card-footer">
#                          Reveal
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/apm-reports-jury-bias/">Bias in the jury selection process</a></h5>
#  </div>
#  <div class="card-body">
#  <p>When selecting a jury, both the defense and the prosecution are allowed to strike potential jurors from the pool. While the potential jurors provide answers to a questionnaire, what kind of role might race play in their selection or rejection?</p>
#  </div>
#  <div class="card-footer">
#                          APM Reports
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/reuters-asylum/">Analyzing the impact of particular judges on the US asylum process</a></h5>
#  </div>
#  <div class="card-body">
#  <p>In U.S. immigration courts, are certain judges and locations more likely to approve or deny claims of asylum?</p>
#  </div>
#  <div class="card-footer">
#                          Reuters
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/propublica-pardons/">Investigating who receives presidential pardons</a></h5>
#  </div>
#  <div class="card-body">
#  <p>An analysis of the presidential pardon process, but also a look into what to do when a very personal dataset doesn't exist.</p>
#  </div>
#  <div class="card-footer">
#                          ProPublica
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/propublica-criminal-sentencing/">An analysis of racial bias in criminal sentencing</a></h5>
#  </div>
#  <div class="card-body">
#  <p>Can an algorithm be racist? An examination of the COMPAS algorithm used as an aid in making sentencing and parole decisions. Also featuring a critique of the critique!</p>
#  </div>
#  <div class="card-footer">
#                          ProPublica
#                      </div>
#  </article>
#  </div>
#  <div class="column col-4 col-lg-6 col-sm-12">
#  <article class="card">
#  <div class="card-header">
#  <h5><a href="/foia-predictor/">Predicting FOIA requests success rates</a></h5>
#  </div>
#  <div class="card-body">
#  <p>Government agencies seem to fulfill or reject FOIA request without rhyme or reason. Can a journalist use machine learning to improve their chances?</p>
#  </div>
#  <div class="card-footer">
#                          data.world
#                      </div>
#  </article>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>]

# %% [markdown]
# ### 4) Use `projects_section.select(...)` to select elements that represent a single project
#
# Assign the list to a variable named `project_els`.

# %%
soup.select(".column.col-4.col-lg-6.col-sm-12")
project_els = soup.select(".column.col-4.col-lg-6.col-sm-12")

# %% [markdown]
# ### 5) Count the number of matching elements, using `len`
#
# Does it match the number of projects you see on the page? (It should.)

# %%
len(project_els)
# Out:
# 26

# %% [markdown]
# ### 6) For each project, print its title, publisher, summary, and link
#
# You'll want to construct a `for` loop. In each iteration of the loop, print out something that looks like this:
#
# ```
# Title: Searching for faulty airbags in vehicle complaints
#
# Publisher: The New York Times
#
# Summary: The National Highway Transportation Safety Administration receives thousands and thousands of vehicle complaints each year. Can we train a computer to filter out leads on Takata airbag malfunctions?
#
# Link: https://investigate.ai/nyt-takata-airbags/
# ---
# ```

# %%
for item in project_els:
    print(item.h5.text)
    print(item.p.text)
    print(item.div.text)
    print(item.find('div', class_="card-footer").text.strip())
    print(f"https://investigate.ai/{item.find('a')['href']}")
# Out:
# Searching for faulty airbags in vehicle complaints
# The National Highway Transportation Safety Administration receives thousands and thousands of vehicle complaints each year. Can we train a computer to filter out leads on Takata airbag malfunctions?
#
# Searching for faulty airbags in vehicle complaints
#
# The New York Times
# https://investigate.ai//nyt-takata-airbags/
# Building a crime classification engine
# Using machine learning as an investigative tool to cast light on years of underreporting by the Los Angeles Police Department.
#
# Building a crime classification engine
#
# Los Angeles Times
# https://investigate.ai//latimes-crime-classification/
# Chinese museum analysis
# A word-count analysis of the names of around 4500 museums in China.
#
# Chinese museum analysis
#
# Caixin
# https://investigate.ai//caixin-museum-word-count/
# Analyzing online safety through app store reviews
# After downloading over a hundred thousand reviews of "random chat apps," how to find reports of bullying, racism, and unwanted sexual behavior.
#
# Analyzing online safety through app store reviews
#
# The Washington Post
# https://investigate.ai//wapo-app-reviews/
# Uncovering abusive doctors that were allowed to continue practicing
# How to comb through 100,000 disciplinary documents without reading each individual one.
#
# Uncovering abusive doctors that were allowed to continue practicing
#
# Atlanta Journal-Constitution
# https://investigate.ai//ajc-doctors-abuse/
# Analyzing the tone of Trump's speeches
# Standard sentiment analysis scores a document on a positive-vs-negative scale. Using the Emotional Lexicon, though, you can add unique emotional measurements like anger, joy, surprise, or fear.
#
# Analyzing the tone of Trump's speeches
#
# The New York Times
# https://investigate.ai//upshot-trump-emolex/
# Detecting special interest model legislation in state laws
# Special interest groups use model legislation to push their agendas in state government. How can we find bills based on these "cut and paste" models?
#
# Detecting special interest model legislation in state laws
#
# USA Today, The Arizona Republic, and the Center for Public Integrity
# https://investigate.ai//azcentral-text-reuse-model-legislation/
# Detecting bots in FCC comment submissions
# The comment period on the FCC's net neutrality decision was flooded with bots. See how one still-in-training data scientist tackled finding re-used comments.
#
# Detecting bots in FCC comment submissions
#
#
# https://investigate.ai//fcc-comments/
# Figuring out what Democratic candidates care about
# In the wide field of Democratic presidential candidates, who cares about what topics and how do these topics change over time?
#
# Figuring out what Democratic candidates care about
#
# Bloomberg
# https://investigate.ai//bloomberg-tweet-topics/
# What does Trump tweet about?
# What does Trump tweet about? An analysis of over 11,000 tweets.
#
# What does Trump tweet about?
#
# The New York Times
# https://investigate.ai//nyt-trump-tweets/
# Examining life expectancy at the local level
# Combine geographically granular life expectancy data with the American Community Survey to see how poverty, education, income, and demographics can affect a community.
#
# Examining life expectancy at the local level
#
# The Associated Press
# https://investigate.ai//ap-regression-unemployment/
# p values and p-hacking
# p-values and the quest for "statistical significance"
#
# p values and p-hacking
#
# FiveThirtyEight
# https://investigate.ai//fivethirtyeight-p-hacking/
# Predicting delays in patching potholes based on demographics
# An analysis of the relationship between race and city sanitation services in Milwaukee.
#
# Predicting delays in patching potholes based on demographics
#
# Milwaukee Journal-Sentinel
# https://investigate.ai//milwaukee-potholes/
# Finding cheating schools in Texas with linear regression
# Some schools in Texas had an odd jump in standardized test scores between different grades. Was it cheating? Linear regression is on the case!
#
# Finding cheating schools in Texas with linear regression
#
# Dallas Morning News
# https://investigate.ai//dmn-texas-school-cheating/
# Measuring the impact of re-segregation on Florida elementary schools
# Using race, income, and other data to predict the performance of schools in Pinellas County, Florida. Along with a linear regression-driven critique.
#
# Measuring the impact of re-segregation on Florida elementary schools
#
# Tampa Bay Times
# https://investigate.ai//tampa-bay-times-schools/
# Analyzing whether larger cars cause more deadly crashes
# Reproducing a research paper on the impact of weight on car accidents, along with a look at a state-based car crash database.
#
# Analyzing whether larger cars cause more deadly crashes
#
# Review of Economic Studies
# https://investigate.ai//car-crashes-weight-regression/
# Tracking equal access to school programs
# Looking at differences in access to advanced classes between schools with wealthy students and schools with poor students.
#
# Tracking equal access to school programs
#
# ProPublica
# https://investigate.ai//propublica-opportunity-gap/
# Investigating who gets a ticket and who gets a warning
# A classic piece of data journalism analyzing ticketing by Massachusetts police, and whether the race or gender of the driver might change the outcome.
#
# Investigating who gets a ticket and who gets a warning
#
# The Boston Globe
# https://investigate.ai//boston-globe-tickets/
# Stanford Open Policing Data
# A giant dataset of standardized data policing data across different states
#
# Stanford Open Policing Data
#
#
# https://investigate.ai//stanford-open-policing/
# Uncovering surveillance planes with BuzzFeed
# From a list of points along a flight's path, how can you say "this looks like a surveillance plane?" And once you've found them, what do you do with the results?
#
# Uncovering surveillance planes with BuzzFeed
#
# BuzzFeed News
# https://investigate.ai//buzzfeed-spy-planes/
# Analyzing mortgage rejections for racial bias
# Based on government-mandated data collection on mortgage granting, are certain banks or areas discriminatory in their lending practices?
#
# Analyzing mortgage rejections for racial bias
#
# Reveal
# https://investigate.ai//reveal-mortgages/
# Bias in the jury selection process
# When selecting a jury, both the defense and the prosecution are allowed to strike potential jurors from the pool. While the potential jurors provide answers to a questionnaire, what kind of role might race play in their selection or rejection?
#
# Bias in the jury selection process
#
# APM Reports
# https://investigate.ai//apm-reports-jury-bias/
# Analyzing the impact of particular judges on the US asylum process
# In U.S. immigration courts, are certain judges and locations more likely to approve or deny claims of asylum?
#
# Analyzing the impact of particular judges on the US asylum process
#
# Reuters
# https://investigate.ai//reuters-asylum/
# Investigating who receives presidential pardons
# An analysis of the presidential pardon process, but also a look into what to do when a very personal dataset doesn't exist.
#
# Investigating who receives presidential pardons
#
# ProPublica
# https://investigate.ai//propublica-pardons/
# An analysis of racial bias in criminal sentencing
# Can an algorithm be racist? An examination of the COMPAS algorithm used as an aid in making sentencing and parole decisions. Also featuring a critique of the critique!
#
# An analysis of racial bias in criminal sentencing
#
# ProPublica
# https://investigate.ai//propublica-criminal-sentencing/
# Predicting FOIA requests success rates
# Government agencies seem to fulfill or reject FOIA request without rhyme or reason. Can a journalist use machine learning to improve their chances?
#
# Predicting FOIA requests success rates
#
# data.world
# https://investigate.ai//foia-predictor/

# %%
item.h5.text
# Out:
# 'Predicting FOIA requests success rates'

# %%
item.p.text
# Out:
# 'Government agencies seem to fulfill or reject FOIA request without rhyme or reason. Can a journalist use machine learning to improve their chances?'

# %%
item
# Out:
# <div class="column col-4 col-lg-6 col-sm-12">
# <article class="card">
# <div class="card-header">
# <h5><a href="/foia-predictor/">Predicting FOIA requests success rates</a></h5>
# </div>
# <div class="card-body">
# <p>Government agencies seem to fulfill or reject FOIA request without rhyme or reason. Can a journalist use machine learning to improve their chances?</p>
# </div>
# <div class="card-footer">
#                         data.world
#                     </div>
# </article>
# </div>

# %%
item.div.text
# Out:
# '\nPredicting FOIA requests success rates\n'

# %%
item.find('p').text
# Out:
# 'Government agencies seem to fulfill or reject FOIA request without rhyme or reason. Can a journalist use machine learning to improve their chances?'

# %%
item.find('div', class_="card-footer").text.strip()
# Out:
# 'data.world'

# %%
item.find("a")["href"]
# Out:
# '/foia-predictor/'

# %%
print(f"https://investigate.ai/{item.find('a')['href']}")
# Out:
# https://investigate.ai//foia-predictor/

# %%
for title in projects_section:
    print("a.href") 
    print("---")
# Out:
# a.href
# ---

# %%
for publisher in projects_section:
    print("div.class = 'card-footer'")
    print("---")
# Out:
# div.class = 'card-footer'
# ---

# %%
for summary in projects_section:
    print("<p>")
    print("---")
# Out:
# <p>
# ---

# %% [markdown]
# ### 7) Now, let's do the same thing, but storing the info in a `pandas` `DataFrame`
#
# Specifically, a `DataFrame` with the columns `title`, `publisher`, `summary`, and `link`.

# %%
for item in project_els:
    print(item.h5.text)
    print(item.p.text)
    print(item.div.text)
    print(item.find('div', class_="card-footer").text.strip())
    print(f"https://investigate.ai/{item.find('a')['href']}")
# Out:
# Searching for faulty airbags in vehicle complaints
# The National Highway Transportation Safety Administration receives thousands and thousands of vehicle complaints each year. Can we train a computer to filter out leads on Takata airbag malfunctions?
#
# Searching for faulty airbags in vehicle complaints
#
# The New York Times
# https://investigate.ai//nyt-takata-airbags/
# Building a crime classification engine
# Using machine learning as an investigative tool to cast light on years of underreporting by the Los Angeles Police Department.
#
# Building a crime classification engine
#
# Los Angeles Times
# https://investigate.ai//latimes-crime-classification/
# Chinese museum analysis
# A word-count analysis of the names of around 4500 museums in China.
#
# Chinese museum analysis
#
# Caixin
# https://investigate.ai//caixin-museum-word-count/
# Analyzing online safety through app store reviews
# After downloading over a hundred thousand reviews of "random chat apps," how to find reports of bullying, racism, and unwanted sexual behavior.
#
# Analyzing online safety through app store reviews
#
# The Washington Post
# https://investigate.ai//wapo-app-reviews/
# Uncovering abusive doctors that were allowed to continue practicing
# How to comb through 100,000 disciplinary documents without reading each individual one.
#
# Uncovering abusive doctors that were allowed to continue practicing
#
# Atlanta Journal-Constitution
# https://investigate.ai//ajc-doctors-abuse/
# Analyzing the tone of Trump's speeches
# Standard sentiment analysis scores a document on a positive-vs-negative scale. Using the Emotional Lexicon, though, you can add unique emotional measurements like anger, joy, surprise, or fear.
#
# Analyzing the tone of Trump's speeches
#
# The New York Times
# https://investigate.ai//upshot-trump-emolex/
# Detecting special interest model legislation in state laws
# Special interest groups use model legislation to push their agendas in state government. How can we find bills based on these "cut and paste" models?
#
# Detecting special interest model legislation in state laws
#
# USA Today, The Arizona Republic, and the Center for Public Integrity
# https://investigate.ai//azcentral-text-reuse-model-legislation/
# Detecting bots in FCC comment submissions
# The comment period on the FCC's net neutrality decision was flooded with bots. See how one still-in-training data scientist tackled finding re-used comments.
#
# Detecting bots in FCC comment submissions
#
#
# https://investigate.ai//fcc-comments/
# Figuring out what Democratic candidates care about
# In the wide field of Democratic presidential candidates, who cares about what topics and how do these topics change over time?
#
# Figuring out what Democratic candidates care about
#
# Bloomberg
# https://investigate.ai//bloomberg-tweet-topics/
# What does Trump tweet about?
# What does Trump tweet about? An analysis of over 11,000 tweets.
#
# What does Trump tweet about?
#
# The New York Times
# https://investigate.ai//nyt-trump-tweets/
# Examining life expectancy at the local level
# Combine geographically granular life expectancy data with the American Community Survey to see how poverty, education, income, and demographics can affect a community.
#
# Examining life expectancy at the local level
#
# The Associated Press
# https://investigate.ai//ap-regression-unemployment/
# p values and p-hacking
# p-values and the quest for "statistical significance"
#
# p values and p-hacking
#
# FiveThirtyEight
# https://investigate.ai//fivethirtyeight-p-hacking/
# Predicting delays in patching potholes based on demographics
# An analysis of the relationship between race and city sanitation services in Milwaukee.
#
# Predicting delays in patching potholes based on demographics
#
# Milwaukee Journal-Sentinel
# https://investigate.ai//milwaukee-potholes/
# Finding cheating schools in Texas with linear regression
# Some schools in Texas had an odd jump in standardized test scores between different grades. Was it cheating? Linear regression is on the case!
#
# Finding cheating schools in Texas with linear regression
#
# Dallas Morning News
# https://investigate.ai//dmn-texas-school-cheating/
# Measuring the impact of re-segregation on Florida elementary schools
# Using race, income, and other data to predict the performance of schools in Pinellas County, Florida. Along with a linear regression-driven critique.
#
# Measuring the impact of re-segregation on Florida elementary schools
#
# Tampa Bay Times
# https://investigate.ai//tampa-bay-times-schools/
# Analyzing whether larger cars cause more deadly crashes
# Reproducing a research paper on the impact of weight on car accidents, along with a look at a state-based car crash database.
#
# Analyzing whether larger cars cause more deadly crashes
#
# Review of Economic Studies
# https://investigate.ai//car-crashes-weight-regression/
# Tracking equal access to school programs
# Looking at differences in access to advanced classes between schools with wealthy students and schools with poor students.
#
# Tracking equal access to school programs
#
# ProPublica
# https://investigate.ai//propublica-opportunity-gap/
# Investigating who gets a ticket and who gets a warning
# A classic piece of data journalism analyzing ticketing by Massachusetts police, and whether the race or gender of the driver might change the outcome.
#
# Investigating who gets a ticket and who gets a warning
#
# The Boston Globe
# https://investigate.ai//boston-globe-tickets/
# Stanford Open Policing Data
# A giant dataset of standardized data policing data across different states
#
# Stanford Open Policing Data
#
#
# https://investigate.ai//stanford-open-policing/
# Uncovering surveillance planes with BuzzFeed
# From a list of points along a flight's path, how can you say "this looks like a surveillance plane?" And once you've found them, what do you do with the results?
#
# Uncovering surveillance planes with BuzzFeed
#
# BuzzFeed News
# https://investigate.ai//buzzfeed-spy-planes/
# Analyzing mortgage rejections for racial bias
# Based on government-mandated data collection on mortgage granting, are certain banks or areas discriminatory in their lending practices?
#
# Analyzing mortgage rejections for racial bias
#
# Reveal
# https://investigate.ai//reveal-mortgages/
# Bias in the jury selection process
# When selecting a jury, both the defense and the prosecution are allowed to strike potential jurors from the pool. While the potential jurors provide answers to a questionnaire, what kind of role might race play in their selection or rejection?
#
# Bias in the jury selection process
#
# APM Reports
# https://investigate.ai//apm-reports-jury-bias/
# Analyzing the impact of particular judges on the US asylum process
# In U.S. immigration courts, are certain judges and locations more likely to approve or deny claims of asylum?
#
# Analyzing the impact of particular judges on the US asylum process
#
# Reuters
# https://investigate.ai//reuters-asylum/
# Investigating who receives presidential pardons
# An analysis of the presidential pardon process, but also a look into what to do when a very personal dataset doesn't exist.
#
# Investigating who receives presidential pardons
#
# ProPublica
# https://investigate.ai//propublica-pardons/
# An analysis of racial bias in criminal sentencing
# Can an algorithm be racist? An examination of the COMPAS algorithm used as an aid in making sentencing and parole decisions. Also featuring a critique of the critique!
#
# An analysis of racial bias in criminal sentencing
#
# ProPublica
# https://investigate.ai//propublica-criminal-sentencing/
# Predicting FOIA requests success rates
# Government agencies seem to fulfill or reject FOIA request without rhyme or reason. Can a journalist use machine learning to improve their chances?
#
# Predicting FOIA requests success rates
#
# data.world
# https://investigate.ai//foia-predictor/

# %%
tpsl_df = pd.DataFrame([{
    "title": item.h5.text,
    "publisher": (item.find('div', class_="card-footer").text.strip()),
    "summary": item.p.text,
    "link": f"https://investigate.ai/{item.find('a')['href']}",}
for item in project_els])

# %%
tpsl_df['summary'].apply(len)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 ['summary'].apply(len)
#
# AttributeError: 'list' object has no attribute 'apply'

# %% [markdown]
# ### 8) Using that `DataFrame`, calculate:

# %% [markdown]
# Who are the most-featured publishers?

# %%
tpsl_df['publisher'].value_counts().head(2)
# Out:
# publisher
# The New York Times    3
# ProPublica            3
# Name: count, dtype: int64

# %% [markdown]
# Which project has the longest summary, in number of characters of text? How long is it?

# %%
tpsl_df['summary'].apply(len)
# Out:
# 0     198
# 1     126
# 2      67
# 3     143
# 4      87
# 5     193
# 6     149
# 7     157
# 8     126
# 9      63
# 10    167
# 11     53
# 12     87
# 13    142
# 14    149
# 15    125
# 16    122
# 17    150
# 18     74
# 19    161
# 20    136
# 21    243
# 22    109
# 23    123
# 24    167
# 25    147
# Name: summary, dtype: int64

# %%
list_number = tpsl_df['summary'].apply(len)

# %%
tpsl_df['list_number']= list_number

# %%
tpsl_df
# Out:
#                                                 title  \
# 0   Searching for faulty airbags in vehicle compla...
# 1              Building a crime classification engine
# 2                             Chinese museum analysis
# 3   Analyzing online safety through app store reviews
# 4   Uncovering abusive doctors that were allowed t...
# 5              Analyzing the tone of Trump's speeches
# 6   Detecting special interest model legislation i...
# 7           Detecting bots in FCC comment submissions
# 8   Figuring out what Democratic candidates care a...
# 9                        What does Trump tweet about?
# 10       Examining life expectancy at the local level
# 11                             p values and p-hacking
# 12  Predicting delays in patching potholes based o...
# 13  Finding cheating schools in Texas with linear ...
# 14  Measuring the impact of re-segregation on Flor...
# 15  Analyzing whether larger cars cause more deadl...
# 16           Tracking equal access to school programs
# 17  Investigating who gets a ticket and who gets a...
# 18                        Stanford Open Policing Data
# 19       Uncovering surveillance planes with BuzzFeed
# 20      Analyzing mortgage rejections for racial bias
# 21                 Bias in the jury selection process
# 22  Analyzing the impact of particular judges on t...
# 23    Investigating who receives presidential pardons
# 24  An analysis of racial bias in criminal sentencing
# 25             Predicting FOIA requests success rates
#
#                                             publisher  \
# 0                                  The New York Times
# 1                                   Los Angeles Times
# 2                                              Caixin
# 3                                 The Washington Post
# 4                        Atlanta Journal-Constitution
# 5                                  The New York Times
# 6   USA Today, The Arizona Republic, and the Cente...
# 7
# 8                                           Bloomberg
# 9                                  The New York Times
# 10                               The Associated Press
# 11                                    FiveThirtyEight
# 12                         Milwaukee Journal-Sentinel
# 13                                Dallas Morning News
# 14                                    Tampa Bay Times
# 15                         Review of Economic Studies
# 16                                         ProPublica
# 17                                   The Boston Globe
# 18
# 19                                      BuzzFeed News
# 20                                             Reveal
# 21                                        APM Reports
# 22                                            Reuters
# 23                                         ProPublica
# 24                                         ProPublica
# 25                                         data.world
#
#                                               summary  \
# 0   The National Highway Transportation Safety Adm...
# 1   Using machine learning as an investigative too...
# 2   A word-count analysis of the names of around 4...
# 3   After downloading over a hundred thousand revi...
# 4   How to comb through 100,000 disciplinary docum...
# 5   Standard sentiment analysis scores a document ...
# 6   Special interest groups use model legislation ...
# 7   The comment period on the FCC's net neutrality...
# 8   In the wide field of Democratic presidential c...
# 9   What does Trump tweet about? An analysis of ov...
# 10  Combine geographically granular life expectanc...
# 11  p-values and the quest for "statistical signif...
# 12  An analysis of the relationship between race a...
# 13  Some schools in Texas had an odd jump in stand...
# 14  Using race, income, and other data to predict ...
# 15  Reproducing a research paper on the impact of ...
# 16  Looking at differences in access to advanced c...
# 17  A classic piece of data journalism analyzing t...
# 18  A giant dataset of standardized data policing ...
# 19  From a list of points along a flight's path, h...
# 20  Based on government-mandated data collection o...
# 21  When selecting a jury, both the defense and th...
# 22  In U.S. immigration courts, are certain judges...
# 23  An analysis of the presidential pardon process...
# 24  Can an algorithm be racist? An examination of ...
# 25  Government agencies seem to fulfill or reject ...
#
#                                                  link  list_number
# 0         https://investigate.ai//nyt-takata-airbags/          198
# 1   https://investigate.ai//latimes-crime-classifi...          126
# 2   https://investigate.ai//caixin-museum-word-count/           67
# 3           https://investigate.ai//wapo-app-reviews/          143
# 4          https://investigate.ai//ajc-doctors-abuse/           87
# 5        https://investigate.ai//upshot-trump-emolex/          193
# 6   https://investigate.ai//azcentral-text-reuse-m...          149
# 7               https://investigate.ai//fcc-comments/          157
# 8     https://investigate.ai//bloomberg-tweet-topics/          126
# 9           https://investigate.ai//nyt-trump-tweets/           63
# 10  https://investigate.ai//ap-regression-unemploy...          167
# 11  https://investigate.ai//fivethirtyeight-p-hack...           53
# 12        https://investigate.ai//milwaukee-potholes/           87
# 13  https://investigate.ai//dmn-texas-school-cheat...          142
# 14   https://investigate.ai//tampa-bay-times-schools/          149
# 15  https://investigate.ai//car-crashes-weight-reg...          125
# 16  https://investigate.ai//propublica-opportunity...          122
# 17      https://investigate.ai//boston-globe-tickets/          150
# 18    https://investigate.ai//stanford-open-policing/           74
# 19       https://investigate.ai//buzzfeed-spy-planes/          161
# 20          https://investigate.ai//reveal-mortgages/          136
# 21     https://investigate.ai//apm-reports-jury-bias/          243
# 22            https://investigate.ai//reuters-asylum/          109
# 23        https://investigate.ai//propublica-pardons/          123
# 24  https://investigate.ai//propublica-criminal-se...          167
# 25            https://investigate.ai//foia-predictor/          147

# %%
list_number2=[]
for a in tpsl_df['summary']:
    list_number2.append(len(a))
list_number2
# Out:
# [198,
#  126,
#  67,
#  143,
#  87,
#  193,
#  149,
#  157,
#  126,
#  63,
#  167,
#  53,
#  87,
#  142,
#  149,
#  125,
#  122,
#  150,
#  74,
#  161,
#  136,
#  243,
#  109,
#  123,
#  167,
#  147]

# %% [markdown]
# How many times longer is it than the average summary?

# %%
tpsl_df.list_number.sort_values(ascending = False)
tpsl_df['list_number'].sort_values(ascending = False)
# Out:
# 21    243
# 0     198
# 5     193
# 10    167
# 24    167
# 19    161
# 7     157
# 17    150
# 6     149
# 14    149
# 25    147
# 3     143
# 13    142
# 20    136
# 1     126
# 8     126
# 15    125
# 23    123
# 16    122
# 22    109
# 12     87
# 4      87
# 18     74
# 2      67
# 9      63
# 11     53
# Name: list_number, dtype: int64

# %%
longest_summary = tpsl_df['list_number'].sort_values(ascending = False)

# %% [markdown]
# ---
#
# ---
#
# ---

# %%
longest_summary/list_number.median()
# Out:
# 21    1.748201
# 0     1.424460
# 5     1.388489
# 10    1.201439
# 24    1.201439
# 19    1.158273
# 7     1.129496
# 17    1.079137
# 6     1.071942
# 14    1.071942
# 25    1.057554
# 3     1.028777
# 13    1.021583
# 20    0.978417
# 1     0.906475
# 8     0.906475
# 15    0.899281
# 23    0.884892
# 16    0.877698
# 22    0.784173
# 12    0.625899
# 4     0.625899
# 18    0.532374
# 2     0.482014
# 9     0.453237
# 11    0.381295
# Name: list_number, dtype: float64
